# %%
a = int(input("enter a value"))
b = int(input("enter b value"))
print("enter the function (+,-,*,/)")
cal = input()
if cal =="+":
    print("Answer is",a + b)
if cal =="-":
    print("Answer is",a - b)
if cal =="*":
     print("Answer is",a * b)
if cal =="/":
    print("Answer is",a / b)
# Out:
# enter a value 12
# enter b value 12
# enter the function (+,-,*,/)
#  -
# Answer is 0

# %%
temp=float(input("Enter the temperature"))
print("choose convertion")
print("1 temp to fahrenheit")
print("2 fahrenheit to temp")

option =input()
if option=="1":
    result=(temp*9/5)+32
    print(" temperature is ",result ,"Fahrenheit")
elif  option=="2":
    result=(temp - 32)*5/9
    print("temperature is ",result,"celcius")
else:
    print("invalid")
# Out:
# Enter the temperature 67
# choose convertion
# 1 temp to fahrenheit
# 2 fahrenheit to temp
#  1
#  temperature is  152.6 Fahrenheit

# %%
a=float(input("Enter a value"))
b=float(input("Enetr b value"))
c=float(input("Enter c value"))
if a>b and a>c:
        print("A is the largest number",a)
if b>a and b>c:
        print("B is the largest  number",b)
else:   
        print("C is the largest number",c)
# Out:
# Enter a value 23.909
# Enetr b value 67.78787
# Enter c value 67.76767767
# B is the largest  number 67.78787

# %%
a=float(input("Enter a value"))
b=float(input("Enetr b value"))
c=float(input("Enter c value"))
if a<b and a<c:
        print("A is the smallest number",a)
if b<a and b<c:
        print("B is the smallest  number",b)
else:   
        print("C is the smallest number",c)
# Out:
# Enter a value 12
# Enetr b value 1
# Enter c value 2
# B is the smallest  number 1.0
